# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
W = np.genfromtxt('wealthChange.txt', delimiter=',')
W.shape
# Out:
# (464, 32)

# %%
W[0].argmax()
# Out:
# 24

# %%
df = pd.DataFrame(W)

# %%
ax = df.plot(figsize=(20,12), legend=False)

# %%
df.mean(axis=1).plot(figsize=(20, 4))

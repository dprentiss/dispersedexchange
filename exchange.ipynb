# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
W = np.genfromtxt('wealthChange.txt', delimiter=',')
W.shape
# Out:
# (143, 256)

# %%
P = np.genfromtxt('mrs.txt', delimiter=',')
P.shape
# Out:
# (144, 256)

# %%
min = W[0].argmin()

# %%
wealth = pd.DataFrame(W)

# %%
ax = wealth.plot(figsize=(20,12), legend=False)

# %%
mrs = pd.DataFrame(P)

# %%
ax = mrs.plot(figsize=(20,12), legend=False)

# %%
wealth[min].plot(figsize=(20, 4))

# %%
fig, ax = plt.subplots(figsize = (20, 6))
ax.bar(range(P[0].size), P[0], log=True)
plt.show()

# %%
fig, ax = plt.subplots(figsize = (20, 6))
ax.bar(range(P[0].size), P[1], log=True)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
W = pd.read_csv('2018-11-04T01.33.35.045093Z-1541295215040s-32a-2g.csv', sep=',')

# %%
df = pd.DataFrame(W)
df.head(5)
# Out:
#    round  trader     good_0     good_1  volume_0  volume_1  price_0   price_1  \
# 0      0       0  16.028974  83.971026       0.0       0.0      1.0  5.238702
# 1      0       1  66.935045  33.064955       0.0       0.0      1.0  0.493986
# 2      0       2  40.207453  59.792547       0.0       0.0      1.0  1.487101
# 3      0       3  10.988820  89.011180       0.0       0.0      1.0  8.100158
# 4      0       4  83.971026  16.028974       0.0       0.0      1.0  0.190887
#
#      utility  wealth
# 0  36.687456     0.0
# 1  47.044705     0.0
# 2  49.031684     0.0
# 3  31.275035     0.0
# 4  36.687456     0.0

# %%
df.pivot(index='round', columns='trader', values='wealth').plot(figsize=(25,12), legend=False)

# %%
df.pivot(index='round', columns='trader', values='utility').plot(figsize=(25,12), legend=False)

# %%
df.pivot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-129d685621db> in <module>()
#       1 fig, ax = plt.subplots(figsize = (20, 6))
# ----> 2 ax.bar(range(32), P[0], log=True)
#       3 plt.show()
#
# NameError: name 'P' is not defined

# %%
fig, ax = plt.subplots(figsize = (20, 6))
ax.bar(range(P[0].size), P[0], log=True)
plt.show()

# %%
fig, ax = plt.subplots(figsize = (20, 6))
ax.bar(range(P[0].size), P[-1], log=True)
plt.show()
# Out:
# /home/dave/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:3443: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=1.0, top=1.0
#   'bottom=%s, top=%s') % (bottom, top))

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
W = pd.read_csv('2018-11-03T22.33.39.698742Z-1541284419692s-32a-2g.csv', sep=',')

# %%
df = pd.DataFrame(W)
df.head(5)
# Out:
#    round  trader     good_0     good_1  volume_0  volume_1  price_0  \
# 0      0       0   9.093130  90.906870       0.0       0.0      1.0
# 1      0       1  82.764642  17.235358       0.0       0.0      1.0
# 2      0       2   5.356853  94.643147       0.0       0.0      1.0
# 3      0       3  17.235358  82.764642       0.0       0.0      1.0
# 4      0       4  86.736733  13.263267       0.0       0.0      1.0
#
#      price_1    utility  wealth
# 0   9.997314  28.751139     0.0
# 1   0.208245  37.768746     0.0
# 2  17.667676  22.516426     0.0
# 3   4.802026  37.768746     0.0
# 4   0.152914  33.917731     0.0

# %%
df.pivot(index='round', columns='trader', values='wealth').plot(figsize=(25,12), legend=False)

# %%
df.pivot(index='round', columns='trader', values='utility').plot(figsize=(25,12), legend=False)

# %%
fig, ax = plt.subplots(figsize = (20, 6))
ax.bar(range(P[0].size), P[0], log=True)
plt.show()

# %%
fig, ax = plt.subplots(figsize = (20, 6))
ax.bar(range(P[0].size), P[-1], log=True)
plt.show()
# Out:
# /home/dave/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:3443: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=1.0, top=1.0
#   'bottom=%s, top=%s') % (bottom, top))

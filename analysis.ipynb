# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
W = pd.read_csv('2018-11-04T01.33.35.045093Z-1541295215040s-32a-2g.csv', sep=',')

# %%
W = W.values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-abc0f96e70fc> in <module>()
# ----> 1 W = W.values
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %%
W = W.reshape(465, 32, 10)

# %%
W[0,:,7]
# Out:
# array([5.23870248e+00, 4.93985695e-01, 1.48710109e+00, 8.10015846e+00,
#        1.90886962e-01, 4.09894701e+00, 6.14349835e+00, 1.02611747e+01,
#        2.22704422e+01, 2.41100876e-01, 5.41951961e-01, 6.12225873e-01,
#        3.54924801e+01, 1.62773707e-01, 1.63338409e+00, 4.14764150e+00,
#        9.74547293e-02, 4.34584880e-01, 1.84518199e+00, 7.95475333e-01,
#        1.25711001e+00, 6.72449241e-01, 2.02435012e+00, 4.76068745e-01,
#        1.23454375e-01, 1.84860600e+01, 5.40948152e-02, 2.30104646e+00,
#        2.43965096e-01, 2.10053697e+00, 4.49025659e-02, 2.81749824e-02])

# %%
fig, ax = plt.subplots(figsize = (25, 6))
ax.plot(W[:,:,8])
plt.show()

# %%
fig, ax = plt.subplots(figsize = (25, 6))
ax.plot(W[:,:,9])
plt.show()

# %%
df.pivot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-129d685621db> in <module>()
#       1 fig, ax = plt.subplots(figsize = (20, 6))
# ----> 2 ax.bar(range(32), P[0], log=True)
#       3 plt.show()
#
# NameError: name 'P' is not defined

# %%
fig, ax = plt.subplots(figsize = (20, 6))
ax.bar(range(P[0].size), P[-1], log=True)
plt.show()
# Out:
# /home/dave/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:3443: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=1.0, top=1.0
#   'bottom=%s, top=%s') % (bottom, top))

# %%
fig, ax = plt.subplots(figsize = (20, 6))
ax.bar(range(32), W[0,:,7], log=False)
plt.show()

# %%
fig, ax = plt.subplots(figsize = (20, 6))
ax.bar(range(32), W[1,:,7], log=False)
plt.show()
